# %% [markdown]
# <font size=8>Text to Query Agents with Monog</font>

# %%
import sys
print(sys.version)
# Out:
# 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]

# %%
# !pip install --quiet pymongo==4.13.2

# %%
# %env MONGODB_URI=mongodb+srv://yaz304lehigh_db_user:WFMXcHr8xtk1AllE@cluster0.eni9iyv.mongodb.net/?appName=Cluster0
# Out:
# env: MONGODB_URI=mongodb+srv://yaz304lehigh_db_user:WFMXcHr8xtk1AllE@cluster0.eni9iyv.mongodb.net/?appName=Cluster0

# %%
import os
from pymongo import MongoClient

MONGODB_URI = os.environ["MONGODB_URI"]

# %%
MONGODB_URI
# Out:
# 'mongodb+srv://yaz304lehigh_db_user:WFMXcHr8xtk1AllE@cluster0.eni9iyv.mongodb.net/?appName=Cluster0'

# %%
# Initialize a MongoDB Python client
mongodb_client = MongoClient(MONGODB_URI, appname="datacamp_text_to_query_course")

# Check the connection to your cluster
ping_result = mongodb_client.admin.command("ping")
print(ping_result)
# Out:
# {'ok': 1}

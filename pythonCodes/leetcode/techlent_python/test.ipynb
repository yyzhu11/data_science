# %% [markdown]
# # test2

# %%
# !jupyter nbconvert --to markdown 0_sort.ipynb
# Out:
# [NbConvertApp] Converting notebook 0_sort.ipynb to markdown
# [NbConvertApp] Support files will be in 0_sort_files\
# [NbConvertApp] Making directory 0_sort_files
# [NbConvertApp] Writing 43564 bytes to 0_sort.md

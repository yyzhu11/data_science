# %% [markdown]
# # Chapter 5: Probability

# %% [markdown]
# ## Conditional Probability

# %% [markdown]
# - Bayes's rule
#
# $ P(A|B) = \frac{P(B|A)P(A)}{P(B)} $
#
# - Law of Total Probability
#
# $P(A) = P(A|B_1)P(B_1) + ... + P(A|B_n)P(B_n) $
#
# - Counting

# %% [markdown]
# ## Easy Problems

# %% [markdown]
# ### Problem 1
#
# Google: Two teams play a series of games (best of 7 — whoever wins 4 games first) in which each team has a 50% chance of winning any given round (no draws allowed). What is the probability that the series goes to 7 games?

# %% [markdown]
# ### problem 2
#
# JP Morgan: Say you roll a die three times. What is the probability of getting two sixes in a row?

# %% [markdown]
# ### Problem 3
#
# Uber: You roll three dice, one after another. What is the probability that you obtain three
# numbers in a strictly increasing order

# %% [markdown]
# ### Problem 4
#
# Zenefits: Assume you have a deck of 100 cards with values ranging from 1 to 100, and that you draw two cards at random without replacement. What is the probability that the number of one card is precisely double that of the other

# %% [markdown]
# ### Problem 5
#
# JP Morgan: Imagine you are in a 3D space. From (0,0,0) to (3,3,3), how many paths are there if you can move only up, right, and forward?

# %% [markdown]
# ### Problem 6
#
# Amazon: One in a thousand people have a particular disease, and the test for the disease is 98% correct in testing for the disease. On the other hand, the test has a 1% error rate if the person being tested does not have the disease. If someone tests positive, what are the odds they have the disease?

# %% [markdown]
# ### Problem 7
#
# Facebook: Assume two coins, one fair (having one side heads and one side tails) and the other unfair (having both sides tails). You pick one at random, flip it five times, and observe that it comes up as tails all five times. What is the probability that you are flipping the unfair coin

# %% [markdown]
# ### Problem 8
#
# Goldman Sachs: Players A and B are playing a game where they take turns flipping a biased coin, with p probability of landing on heads (and winning). Player A starts the game, and then the players pass the coin back and forth until one person flips heads and wins. What is the probability that A wins?

# %% [markdown]
# ### Problem 9
#
# Microsoft: Three friends in Seattle each told you it is rainy, and each person has a 1 /3 probability
# of lying. What is the probability that Seattle is rainy, assuming that the likelihood of rain on any given day is 0.25?

# %% [markdown]
# ### Problem 10
#
# Bloomberg: You draw a circle and choose two chords at random. What is the probability that those chords will intersect

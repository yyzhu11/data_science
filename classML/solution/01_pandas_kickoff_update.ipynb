# %% [markdown]
# # 1. import pandas

# %%
import pandas as pd

# %% [markdown]
# # 2. Load data into pandas as a dataframe

# %%
#df = pd.read_csv('../data/sales.csv', nrows=500)
df = pd.read_csv('sales.csv', nrows = 500)

# %% [markdown]
# **Kownledge**:
# 1. **read_csv** is for csv file. Many functions can be used for other formats, for example **read_excel** is for xsl and xslx files.
# 2. **nrows=500** means we only read the first 500 rows from the file.
# 3. If you move your cursor between the parentheses (by clicking any character between the parentheses), then hold down the key **"shift"** and type **"tab"** for twice, you can get the information for all the arguments of read_csv. Set the arguments you need to change the way you want to load data.

# %% [markdown]
# # 3. Have a glance of the data

# %%
df.head(10)
# Out:
#     cost     price        weight purchase_date product_type   product_level  \
# 0  $333k  $300,492   3 Ton 90 Kg   Dec 19 2008          Q,B        advanced
# 1    NaN  $430,570   3 Ton 30 Kg   Sep 10 1997          J,D           basic
# 2  $270k  $213,070   3 Ton 40 Kg   Sep 05 2001          J,D           basic
# 3    NaN  $229,174   3 Ton 50 Kg   Dec 23 2016            U        advanced
# 4   $97k  $122,659  2 Ton 970 Kg   Jan 12 2000          D,R        advanced
# 5   $59k   $60,320  2 Ton 930 Kg   Aug 19 2011            H  super advanced
# 6    NaN  $182,233  3 Ton 300 Kg   Oct 11 1996            S  super advanced
# 7    NaN   $41,155   3 Ton 80 Kg   Jan 08 2010          B,A        advanced
# 8   $66k  $180,759  3 Ton 330 Kg   Aug 01 2014            H  super advanced
# 9  $119k  $182,517  2 Ton 970 Kg   Feb 04 2005          K,D        advanced
#
#     maker                                         ingredient       height  \
# 0  M14122                                  IN732052,IN732053  2.76 meters
# 1     NaN       IN732054,IN732055,IN732056,IN732057,IN732058  2.67 meters
# 2     NaN                         IN732054,IN732059,IN732060   3.0 meters
# 3  M14123                         IN732061,IN732062,IN732063   2.5 meters
# 4     NaN                         IN732064,IN732065,IN732066  2.47 meters
# 5  M14124  IN732067,IN732068,IN732069,IN732070,IN732071,I...  2.71 meters
# 6  M14125                                  IN732073,IN732074  3.01 meters
# 7  M14126                                           IN732075  2.97 meters
# 8     NaN  IN732076,IN732077,IN732073,IN732078,IN732079,I...  2.71 meters
# 9  M14127                         IN732085,IN732086,IN732087  2.84 meters
#
#     width  depth
# 0   97 cm  26 cm
# 1   98 cm  26 cm
# 2   93 cm  24 cm
# 3  102 cm  27 cm
# 4  101 cm  26 cm
# 5   96 cm  25 cm
# 6   96 cm  25 cm
# 7   94 cm  25 cm
# 8  102 cm  27 cm
# 9   94 cm  25 cm

# %% [markdown]
# **Knowledge**: Again, you can use **shift + tab** to get more information about function head.

# %% [markdown]
# **Example**: Get names of columns

# %%
df.columns
# Out:
# Index(['cost', 'price', 'weight', 'purchase_date', 'product_type',
#        'product_level', 'maker', 'ingredient', 'height', 'width', 'depth'],
#       dtype='object')

# %% [markdown]
# **Example**: Get indices

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %% [markdown]
# <font color='red'>Assignment:</font> Get the number of rows and number of columns.

# %%
len(df.index)
# Out:
# 500

# %%
len(df.columns)
# Out:
# 11

# %%
df.shape
# Out:
# (500, 11)

# %%
df.shape[0]
# Out:
# 500

# %%
df.shape[1]
# Out:
# 11

# %% [markdown]
# # 4. Get a slice of the dataframe

# %% [markdown]
# ## 4.1 Get a column

# %% [markdown]
# **Example:** use dot

# %%
df.cost.head()
# Out:
# 0    $333k
# 1      NaN
# 2    $270k
# 3      NaN
# 4     $97k
# Name: cost, dtype: object

# %% [markdown]
# **Example:** use []

# %%
df['cost'].head()
# Out:
# 0    $333k
# 1      NaN
# 2    $270k
# 3      NaN
# 4     $97k
# Name: cost, dtype: object

# %%
# when do we have to use ['']?
# 1. the column name is not a legal variable name (e.g., containing space & special characters, starting with numbers) 
# 2. initiate a new column

# %%
df["1a"] = 1

# %%
df["1a"]

# %% [markdown]
# ## 4.2 Get a few columns

# %%
df[['cost', 'price', 'weight', 'purchase_date']].head()
# Out:
#     cost     price        weight purchase_date
# 0  $333k  $300,492   3 Ton 90 Kg   Dec 19 2008
# 1    NaN  $430,570   3 Ton 30 Kg   Sep 10 1997
# 2  $270k  $213,070   3 Ton 40 Kg   Sep 05 2001
# 3    NaN  $229,174   3 Ton 50 Kg   Dec 23 2016
# 4   $97k  $122,659  2 Ton 970 Kg   Jan 12 2000

# %% [markdown]
# <font color='red'>Question:</font> What is the difference between **df["cost"]** and **df[["cost"]]**? Use **type** to find out.

# %%
type(df['cost'])
# Out:
# pandas.core.series.Series

# %%
type(df[['cost']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### ['cost'] gives result in the form of Series while [['cost']] gives a DataFrame

# %% [markdown]
# ## 4.3 Get rows

# %%
df.iloc[5:15,:]
# Out:
#      cost     price        weight purchase_date product_type   product_level  \
# 5    $59k   $60,320  2 Ton 930 Kg   Aug 19 2011            H  super advanced
# 6     NaN  $182,233  3 Ton 300 Kg   Oct 11 1996            S  super advanced
# 7     NaN   $41,155   3 Ton 80 Kg   Jan 08 2010          B,A        advanced
# 8    $66k  $180,759  3 Ton 330 Kg   Aug 01 2014            H  super advanced
# 9   $119k  $182,517  2 Ton 970 Kg   Feb 04 2005          K,D        advanced
# 10  $160k  $168,762  3 Ton 440 Kg   Oct 28 2016            H  super advanced
# 11   $81k  $228,868  2 Ton 940 Kg   Apr 04 2008            N        advanced
# 12  $191k   $79,384  3 Ton 200 Kg   Dec 21 2001            U  super advanced
# 13    NaN  $118,628   3 Ton 50 Kg   Dec 15 2006          U,A        advanced
# 14    NaN  $204,305   3 Ton 20 Kg   Jan 29 2010          K,D        advanced
#
#      maker                                         ingredient       height  \
# 5   M14124  IN732067,IN732068,IN732069,IN732070,IN732071,I...  2.71 meters
# 6   M14125                                  IN732073,IN732074  3.01 meters
# 7   M14126                                           IN732075  2.97 meters
# 8      NaN  IN732076,IN732077,IN732073,IN732078,IN732079,I...  2.71 meters
# 9   M14127                         IN732085,IN732086,IN732087  2.84 meters
# 10  M14128       IN732088,IN732089,IN732090,IN732091,IN732092  2.91 meters
# 11  M14129                IN732093,IN732094,IN732095,IN732096  2.52 meters
# 12  M14130       IN732097,IN732098,IN732099,IN732100,IN732101  2.87 meters
# 13  M14131                                  IN732074,IN732102  2.63 meters
# 14  M14132                IN732103,IN732104,IN732105,IN732106  2.54 meters
#
#      width  depth
# 5    96 cm  25 cm
# 6    96 cm  25 cm
# 7    94 cm  25 cm
# 8   102 cm  27 cm
# 9    94 cm  25 cm
# 10  100 cm  26 cm
# 11   99 cm  26 cm
# 12   97 cm  25 cm
# 13   99 cm  26 cm
# 14  100 cm  26 cm

# %% [markdown]
# ## 4.4 Get a sub matrix

# %%
df.iloc[5:15,2:7]
# Out:
#           weight purchase_date product_type   product_level   maker
# 5   2 Ton 930 Kg   Aug 19 2011            H  super advanced  M14124
# 6   3 Ton 300 Kg   Oct 11 1996            S  super advanced  M14125
# 7    3 Ton 80 Kg   Jan 08 2010          B,A        advanced  M14126
# 8   3 Ton 330 Kg   Aug 01 2014            H  super advanced     NaN
# 9   2 Ton 970 Kg   Feb 04 2005          K,D        advanced  M14127
# 10  3 Ton 440 Kg   Oct 28 2016            H  super advanced  M14128
# 11  2 Ton 940 Kg   Apr 04 2008            N        advanced  M14129
# 12  3 Ton 200 Kg   Dec 21 2001            U  super advanced  M14130
# 13   3 Ton 50 Kg   Dec 15 2006          U,A        advanced  M14131
# 14   3 Ton 20 Kg   Jan 29 2010          K,D        advanced  M14132

# %%
df.loc[5:15,"weight":"product_type"]
# Out:
#           weight purchase_date product_type
# 5   2 Ton 930 Kg   Aug 19 2011            H
# 6   3 Ton 300 Kg   Oct 11 1996            S
# 7    3 Ton 80 Kg   Jan 08 2010          B,A
# 8   3 Ton 330 Kg   Aug 01 2014            H
# 9   2 Ton 970 Kg   Feb 04 2005          K,D
# 10  3 Ton 440 Kg   Oct 28 2016            H
# 11  2 Ton 940 Kg   Apr 04 2008            N
# 12  3 Ton 200 Kg   Dec 21 2001            U
# 13   3 Ton 50 Kg   Dec 15 2006          U,A
# 14   3 Ton 20 Kg   Jan 29 2010          K,D
# 15  3 Ton 190 Kg   May 13 1998            H

# %%
df.loc[5:15,:]
# Out:
#      cost     price        weight purchase_date product_type   product_level  \
# 5    $59k   $60,320  2 Ton 930 Kg   Aug 19 2011            H  super advanced
# 6     NaN  $182,233  3 Ton 300 Kg   Oct 11 1996            S  super advanced
# 7     NaN   $41,155   3 Ton 80 Kg   Jan 08 2010          B,A        advanced
# 8    $66k  $180,759  3 Ton 330 Kg   Aug 01 2014            H  super advanced
# 9   $119k  $182,517  2 Ton 970 Kg   Feb 04 2005          K,D        advanced
# 10  $160k  $168,762  3 Ton 440 Kg   Oct 28 2016            H  super advanced
# 11   $81k  $228,868  2 Ton 940 Kg   Apr 04 2008            N        advanced
# 12  $191k   $79,384  3 Ton 200 Kg   Dec 21 2001            U  super advanced
# 13    NaN  $118,628   3 Ton 50 Kg   Dec 15 2006          U,A        advanced
# 14    NaN  $204,305   3 Ton 20 Kg   Jan 29 2010          K,D        advanced
# 15    NaN   $20,711  3 Ton 190 Kg   May 13 1998            H  super advanced
#
#      maker                                         ingredient       height  \
# 5   M14124  IN732067,IN732068,IN732069,IN732070,IN732071,I...  2.71 meters
# 6   M14125                                  IN732073,IN732074  3.01 meters
# 7   M14126                                           IN732075  2.97 meters
# 8      NaN  IN732076,IN732077,IN732073,IN732078,IN732079,I...  2.71 meters
# 9   M14127                         IN732085,IN732086,IN732087  2.84 meters
# 10  M14128       IN732088,IN732089,IN732090,IN732091,IN732092  2.91 meters
# 11  M14129                IN732093,IN732094,IN732095,IN732096  2.52 meters
# 12  M14130       IN732097,IN732098,IN732099,IN732100,IN732101  2.87 meters
# 13  M14131                                  IN732074,IN732102  2.63 meters
# 14  M14132                IN732103,IN732104,IN732105,IN732106  2.54 meters
# 15  M14133                                           IN732094  2.96 meters
#
#      width  depth
# 5    96 cm  25 cm
# 6    96 cm  25 cm
# 7    94 cm  25 cm
# 8   102 cm  27 cm
# 9    94 cm  25 cm
# 10  100 cm  26 cm
# 11   99 cm  26 cm
# 12   97 cm  25 cm
# 13   99 cm  26 cm
# 14  100 cm  26 cm
# 15   96 cm  25 cm

# %% [markdown]
# <font color='red'>Question:</font> What is the difference between **iloc** and **loc**.

# %% [markdown]
# ### iloc is index based and loc is label based.

# %% [markdown]
# ## 4.5 Get rows with filters

# %%
df[df.product_level == 'advanced'].head()
# Out:
#     cost     price        weight purchase_date product_type product_level  \
# 0  $333k  $300,492   3 Ton 90 Kg   Dec 19 2008          Q,B      advanced
# 3    NaN  $229,174   3 Ton 50 Kg   Dec 23 2016            U      advanced
# 4   $97k  $122,659  2 Ton 970 Kg   Jan 12 2000          D,R      advanced
# 7    NaN   $41,155   3 Ton 80 Kg   Jan 08 2010          B,A      advanced
# 9  $119k  $182,517  2 Ton 970 Kg   Feb 04 2005          K,D      advanced
#
#     maker                  ingredient       height   width  depth
# 0  M14122           IN732052,IN732053  2.76 meters   97 cm  26 cm
# 3  M14123  IN732061,IN732062,IN732063   2.5 meters  102 cm  27 cm
# 4     NaN  IN732064,IN732065,IN732066  2.47 meters  101 cm  26 cm
# 7  M14126                    IN732075  2.97 meters   94 cm  25 cm
# 9  M14127  IN732085,IN732086,IN732087  2.84 meters   94 cm  25 cm

# %%
df[(df.product_level == 'advanced') | (df.product_level == 'super advanced')]
# Out:
#       cost     price        weight purchase_date product_type   product_level  \
# 0    $333k  $300,492   3 Ton 90 Kg   Dec 19 2008          Q,B        advanced
# 3      NaN  $229,174   3 Ton 50 Kg   Dec 23 2016            U        advanced
# 4     $97k  $122,659  2 Ton 970 Kg   Jan 12 2000          D,R        advanced
# 5     $59k   $60,320  2 Ton 930 Kg   Aug 19 2011            H  super advanced
# 6      NaN  $182,233  3 Ton 300 Kg   Oct 11 1996            S  super advanced
# ..     ...       ...           ...           ...          ...             ...
# 493  $128k   $73,244   3 Ton 80 Kg   Jun 20 2003          F,H  super advanced
# 494    NaN  $249,915  3 Ton 140 Kg   Jan 22 1999            R        advanced
# 496  $395k  $515,473  3 Ton 180 Kg   Jan 14 2011            K        advanced
# 497   $18k   $78,582  2 Ton 970 Kg   May 04 2007            D  super advanced
# 498  $262k  $434,234  2 Ton 970 Kg   Apr 06 2007          K,D        advanced
#
#       maker                                         ingredient       height  \
# 0    M14122                                  IN732052,IN732053  2.76 meters
# 3    M14123                         IN732061,IN732062,IN732063   2.5 meters
# 4       NaN                         IN732064,IN732065,IN732066  2.47 meters
# 5    M14124  IN732067,IN732068,IN732069,IN732070,IN732071,I...  2.71 meters
# 6    M14125                                  IN732073,IN732074  3.01 meters
# ..      ...                                                ...          ...
# 493  M14294                IN732097,IN732436,IN732067,IN733034   2.5 meters
# 494  M14407                                  IN732428,IN732231  2.87 meters
# 496  M14409  IN732688,IN732325,IN733035,IN733036,IN732984,I...  2.86 meters
# 497  M14410                IN732456,IN732989,IN733038,IN732108  2.36 meters
# 498  M14261  IN732217,IN732932,IN732566,IN732187,IN732345,I...   2.4 meters
#
#       width  depth
# 0     97 cm  26 cm
# 3    102 cm  27 cm
# 4    101 cm  26 cm
# 5     96 cm  25 cm
# 6     96 cm  25 cm
# ..      ...    ...
# 493  102 cm  27 cm
# 494   96 cm  25 cm
# 496   97 cm  25 cm
# 497  103 cm  27 cm
# 498  102 cm  27 cm
#
# [407 rows x 11 columns]

# %%
df[(df.product_level.isin(['advanced','super advanced']))]
# Out:
#       cost     price        weight purchase_date product_type   product_level  \
# 0    $333k  $300,492   3 Ton 90 Kg   Dec 19 2008          Q,B        advanced
# 3      NaN  $229,174   3 Ton 50 Kg   Dec 23 2016            U        advanced
# 4     $97k  $122,659  2 Ton 970 Kg   Jan 12 2000          D,R        advanced
# 5     $59k   $60,320  2 Ton 930 Kg   Aug 19 2011            H  super advanced
# 6      NaN  $182,233  3 Ton 300 Kg   Oct 11 1996            S  super advanced
# ..     ...       ...           ...           ...          ...             ...
# 493  $128k   $73,244   3 Ton 80 Kg   Jun 20 2003          F,H  super advanced
# 494    NaN  $249,915  3 Ton 140 Kg   Jan 22 1999            R        advanced
# 496  $395k  $515,473  3 Ton 180 Kg   Jan 14 2011            K        advanced
# 497   $18k   $78,582  2 Ton 970 Kg   May 04 2007            D  super advanced
# 498  $262k  $434,234  2 Ton 970 Kg   Apr 06 2007          K,D        advanced
#
#       maker                                         ingredient       height  \
# 0    M14122                                  IN732052,IN732053  2.76 meters
# 3    M14123                         IN732061,IN732062,IN732063   2.5 meters
# 4       NaN                         IN732064,IN732065,IN732066  2.47 meters
# 5    M14124  IN732067,IN732068,IN732069,IN732070,IN732071,I...  2.71 meters
# 6    M14125                                  IN732073,IN732074  3.01 meters
# ..      ...                                                ...          ...
# 493  M14294                IN732097,IN732436,IN732067,IN733034   2.5 meters
# 494  M14407                                  IN732428,IN732231  2.87 meters
# 496  M14409  IN732688,IN732325,IN733035,IN733036,IN732984,I...  2.86 meters
# 497  M14410                IN732456,IN732989,IN733038,IN732108  2.36 meters
# 498  M14261  IN732217,IN732932,IN732566,IN732187,IN732345,I...   2.4 meters
#
#       width  depth
# 0     97 cm  26 cm
# 3    102 cm  27 cm
# 4    101 cm  26 cm
# 5     96 cm  25 cm
# 6     96 cm  25 cm
# ..      ...    ...
# 493  102 cm  27 cm
# 494   96 cm  25 cm
# 496   97 cm  25 cm
# 497  103 cm  27 cm
# 498  102 cm  27 cm
#
# [407 rows x 11 columns]

# %%
df[(df.product_level.isin({'advanced','super advanced'}))]
# Out:
#       cost     price        weight purchase_date product_type   product_level  \
# 0    $333k  $300,492   3 Ton 90 Kg   Dec 19 2008          Q,B        advanced
# 3      NaN  $229,174   3 Ton 50 Kg   Dec 23 2016            U        advanced
# 4     $97k  $122,659  2 Ton 970 Kg   Jan 12 2000          D,R        advanced
# 5     $59k   $60,320  2 Ton 930 Kg   Aug 19 2011            H  super advanced
# 6      NaN  $182,233  3 Ton 300 Kg   Oct 11 1996            S  super advanced
# ..     ...       ...           ...           ...          ...             ...
# 493  $128k   $73,244   3 Ton 80 Kg   Jun 20 2003          F,H  super advanced
# 494    NaN  $249,915  3 Ton 140 Kg   Jan 22 1999            R        advanced
# 496  $395k  $515,473  3 Ton 180 Kg   Jan 14 2011            K        advanced
# 497   $18k   $78,582  2 Ton 970 Kg   May 04 2007            D  super advanced
# 498  $262k  $434,234  2 Ton 970 Kg   Apr 06 2007          K,D        advanced
#
#       maker                                         ingredient       height  \
# 0    M14122                                  IN732052,IN732053  2.76 meters
# 3    M14123                         IN732061,IN732062,IN732063   2.5 meters
# 4       NaN                         IN732064,IN732065,IN732066  2.47 meters
# 5    M14124  IN732067,IN732068,IN732069,IN732070,IN732071,I...  2.71 meters
# 6    M14125                                  IN732073,IN732074  3.01 meters
# ..      ...                                                ...          ...
# 493  M14294                IN732097,IN732436,IN732067,IN733034   2.5 meters
# 494  M14407                                  IN732428,IN732231  2.87 meters
# 496  M14409  IN732688,IN732325,IN733035,IN733036,IN732984,I...  2.86 meters
# 497  M14410                IN732456,IN732989,IN733038,IN732108  2.36 meters
# 498  M14261  IN732217,IN732932,IN732566,IN732187,IN732345,I...   2.4 meters
#
#       width  depth
# 0     97 cm  26 cm
# 3    102 cm  27 cm
# 4    101 cm  26 cm
# 5     96 cm  25 cm
# 6     96 cm  25 cm
# ..      ...    ...
# 493  102 cm  27 cm
# 494   96 cm  25 cm
# 496   97 cm  25 cm
# 497  103 cm  27 cm
# 498  102 cm  27 cm
#
# [407 rows x 11 columns]

# %% [markdown]
# <font color='red'>Assignment:</font> Get a sub matrix with columns "cost", "price", and "pruchase_date". Filter out the rows in which "cost" values are "NaN". Hint: use "pandas.notnull()".

# %%
df[df.cost.notnull()][['cost', 'price', 'purchase_date']]
# Out:
#       cost     price purchase_date
# 0    $333k  $300,492   Dec 19 2008
# 2    $270k  $213,070   Sep 05 2001
# 4     $97k  $122,659   Jan 12 2000
# 5     $59k   $60,320   Aug 19 2011
# 8     $66k  $180,759   Aug 01 2014
# ..     ...       ...           ...
# 495  $176k   $27,452   Jul 24 2009
# 496  $395k  $515,473   Jan 14 2011
# 497   $18k   $78,582   May 04 2007
# 498  $262k  $434,234   Apr 06 2007
# 499   $84k  $118,926   Jan 10 2003
#
# [350 rows x 3 columns]

# %%
df[['cost', 'price', 'purchase_date']].dropna(subset = ['cost'])
# Out:
#       cost     price purchase_date
# 0    $333k  $300,492   Dec 19 2008
# 2    $270k  $213,070   Sep 05 2001
# 4     $97k  $122,659   Jan 12 2000
# 5     $59k   $60,320   Aug 19 2011
# 8     $66k  $180,759   Aug 01 2014
# ..     ...       ...           ...
# 495  $176k   $27,452   Jul 24 2009
# 496  $395k  $515,473   Jan 14 2011
# 497   $18k   $78,582   May 04 2007
# 498  $262k  $434,234   Apr 06 2007
# 499   $84k  $118,926   Jan 10 2003
#
# [350 rows x 3 columns]

# %%
df.func1.func2.func3  #you can chain up functions

# %%
df.cost.notnull()  # elementwise
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 495     True
# 496     True
# 497     True
# 498     True
# 499     True
# Name: cost, Length: 500, dtype: bool

# %%
df.cost.head()
# Out:
# 0    $333k
# 1      NaN
# 2    $270k
# 3      NaN
# 4     $97k
# Name: cost, dtype: object

# %%
# about NaN - Not a Number

# %%
df.loc[3,"cost"]
# Out:
# nan

# %%
type(df.loc[3,"cost"])
# Out:
# float

# %%
import numpy as np
df.loc[3,"cost"] == np.nan
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
# think NaN as an ever-changing invisible alien

# %%
pd.isnull(df.loc[3,"cost"])
# Out:
# True

# %%
pd.isna(df.loc[3,"cost"])
# Out:
# True

# %%
pd.isnull(df.cost)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: cost, Length: 500, dtype: bool

# %%
pd.isna(df.cost)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: cost, Length: 500, dtype: bool

# %%
pd.isna(df)
# Out:
#       cost  price  weight  purchase_date  product_type  product_level  maker  \
# 0    False  False   False          False         False          False  False
# 1     True  False   False          False         False          False   True
# 2    False  False   False          False         False          False   True
# 3     True  False   False          False         False          False  False
# 4    False  False   False          False         False          False   True
# ..     ...    ...     ...            ...           ...            ...    ...
# 495  False  False   False          False         False          False  False
# 496  False  False   False          False         False          False  False
# 497  False  False   False          False         False          False  False
# 498  False  False   False          False         False          False  False
# 499  False  False   False          False         False          False   True
#
#      ingredient  height  width  depth
# 0         False   False  False  False
# 1         False   False  False  False
# 2         False   False  False  False
# 3         False   False  False  False
# 4         False   False  False  False
# ..          ...     ...    ...    ...
# 495       False   False  False  False
# 496       False   False  False  False
# 497       False   False  False  False
# 498       False   False  False  False
# 499        True   False  False  False
#
# [500 rows x 11 columns]

# %%
pd.isnull(df)
# Out:
#       cost  price  weight  purchase_date  product_type  product_level  maker  \
# 0    False  False   False          False         False          False  False
# 1     True  False   False          False         False          False   True
# 2    False  False   False          False         False          False   True
# 3     True  False   False          False         False          False  False
# 4    False  False   False          False         False          False   True
# ..     ...    ...     ...            ...           ...            ...    ...
# 495  False  False   False          False         False          False  False
# 496  False  False   False          False         False          False  False
# 497  False  False   False          False         False          False  False
# 498  False  False   False          False         False          False  False
# 499  False  False   False          False         False          False   True
#
#      ingredient  height  width  depth
# 0         False   False  False  False
# 1         False   False  False  False
# 2         False   False  False  False
# 3         False   False  False  False
# 4         False   False  False  False
# ..          ...     ...    ...    ...
# 495       False   False  False  False
# 496       False   False  False  False
# 497       False   False  False  False
# 498       False   False  False  False
# 499        True   False  False  False
#
# [500 rows x 11 columns]

# %%
pd.notna(df)
# Out:
#       cost  price  weight  purchase_date  product_type  product_level  maker  \
# 0     True   True    True           True          True           True   True
# 1    False   True    True           True          True           True  False
# 2     True   True    True           True          True           True  False
# 3    False   True    True           True          True           True   True
# 4     True   True    True           True          True           True  False
# ..     ...    ...     ...            ...           ...            ...    ...
# 495   True   True    True           True          True           True   True
# 496   True   True    True           True          True           True   True
# 497   True   True    True           True          True           True   True
# 498   True   True    True           True          True           True   True
# 499   True   True    True           True          True           True  False
#
#      ingredient  height  width  depth
# 0          True    True   True   True
# 1          True    True   True   True
# 2          True    True   True   True
# 3          True    True   True   True
# 4          True    True   True   True
# ..          ...     ...    ...    ...
# 495        True    True   True   True
# 496        True    True   True   True
# 497        True    True   True   True
# 498        True    True   True   True
# 499       False    True   True   True
#
# [500 rows x 11 columns]

# %%
pd.notnull(df)
# Out:
#       cost  price  weight  purchase_date  product_type  product_level  maker  \
# 0     True   True    True           True          True           True   True
# 1    False   True    True           True          True           True  False
# 2     True   True    True           True          True           True  False
# 3    False   True    True           True          True           True   True
# 4     True   True    True           True          True           True  False
# ..     ...    ...     ...            ...           ...            ...    ...
# 495   True   True    True           True          True           True   True
# 496   True   True    True           True          True           True   True
# 497   True   True    True           True          True           True   True
# 498   True   True    True           True          True           True   True
# 499   True   True    True           True          True           True  False
#
#      ingredient  height  width  depth
# 0          True    True   True   True
# 1          True    True   True   True
# 2          True    True   True   True
# 3          True    True   True   True
# 4          True    True   True   True
# ..          ...     ...    ...    ...
# 495        True    True   True   True
# 496        True    True   True   True
# 497        True    True   True   True
# 498        True    True   True   True
# 499       False    True   True   True
#
# [500 rows x 11 columns]

# %%
np.isnull(df.cost)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 np.isnull(df.cost)
#
# File ~\Anaconda3\lib\site-packages\numpy\__init__.py:313, in __getattr__(attr)
#     310     from .testing import Tester
#     311     return Tester
# --> 313 raise AttributeError("module {!r} has no attribute "
#     314                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'isnull'

# %%
pd.isnull(df.cost)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: cost, Length: 500, dtype: bool

# %%
pd.isna(df.cost)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: cost, Length: 500, dtype: bool

# %%
np.isnan(df.loc[3,"cost"])
# Out:
# True

# %%
np.isnull(df.loc[3,"cost"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 np.isnull(df.loc[3,"cost"])
#
# File ~\Anaconda3\lib\site-packages\numpy\__init__.py:313, in __getattr__(attr)
#     310     from .testing import Tester
#     311     return Tester
# --> 313 raise AttributeError("module {!r} has no attribute "
#     314                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'isnull'

# %%
df.loc[3,"cost"] is np.nan
# Out:
# True

# %%
# None vs NaN
a = None
a == None
# Out:
# True

# %%
a is None
# Out:
# True

# %%
np.nan == None
# Out:
# False
